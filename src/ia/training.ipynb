# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import spicy
from tensorflow.keras.models import load_model
from tensorflow.keras.models import save_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense



key_day = "SS"
data_dir = f'./data/data{key_day}'
dataset_dir = f'./data/dataset{key_day}'

##ESCOGER MENOR TAMAÑO DE CARPETA

folders = [folder for folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, folder))]
num_hermandades = len(folders)
tamanos =[]
for folder in folders:
    folder_path = os.path.join(data_dir, folder)
    file_count = len(os.listdir(folder_path))
    tamanos.append(file_count)

menor = min(tamanos)
print(menor)
'''
##LIMITAR A MENOR TAMAÑO DE CARPETA
carpeta_fuente = data_dir
carpeta_destino = dataset_dir

carpetas = os.listdir(carpeta_fuente)

for carpeta in carpetas:
    if not carpeta.startswith("."):
        imagenes = os.listdir(carpeta_fuente + '/' + carpeta)

        for i, nombreimg in enumerate(imagenes):
            if i < menor:
                if not nombreimg.startswith("."):
                    shutil.copy(carpeta_fuente + '/' + carpeta + '/' + nombreimg, carpeta_destino + '/' + carpeta + '/' + nombreimg)
'''
##CREAR GENERADORES DE IMAGENES CON DATA AUGMENTATION
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    zoom_range = [0.5, 1.5],
    validation_split=0.2 #20% para pruebas
)

##GENERADORES PARA ENTRENAMIENTO Y PRUEBAS
data_gen_entrenamiento = datagen.flow_from_directory(data_dir, target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory(data_dir, target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')
# Out:
# 12
# Found 132 images belonging to 5 classes.
# Found 31 images belonging to 5 classes.

# %%
from tensorflow.keras.applications import DenseNet121

densenet = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
densenet.trainable = False

modelo_densenet = tf.keras.Sequential([
    densenet,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_densenet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historialDN = modelo_densenet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_densenet, f'./models/{key_day}/{key_day}DENSENET{EPOCAS}.h5')
# Out:
# Epoch 1/100
# 5/5 [==============================] - 29s 4s/step - loss: 1.7862 - accuracy: 0.2803 - val_loss: 1.6491 - val_accuracy: 0.2903
# Epoch 2/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.6519 - accuracy: 0.2879 - val_loss: 1.6056 - val_accuracy: 0.3548
# Epoch 3/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.5207 - accuracy: 0.3106 - val_loss: 1.6085 - val_accuracy: 0.3548
# Epoch 4/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.5254 - accuracy: 0.3485 - val_loss: 1.4832 - val_accuracy: 0.3871
# Epoch 5/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.4484 - accuracy: 0.4167 - val_loss: 1.6004 - val_accuracy: 0.2903
# Epoch 6/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.4355 - accuracy: 0.4015 - val_loss: 1.3234 - val_accuracy: 0.3871
# Epoch 7/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.3436 - accuracy: 0.4773 - val_loss: 1.3943 - val_accuracy: 0.4839
# Epoch 8/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.3212 - accuracy: 0.4773 - val_loss: 1.3833 - val_accuracy: 0.5161
# Epoch 9/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.2694 - accuracy: 0.5227 - val_loss: 1.2497 - val_accuracy: 0.5161
# Epoch 10/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.2665 - accuracy: 0.5227 - val_loss: 1.4173 - val_accuracy: 0.4516
# Epoch 11/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.2354 - accuracy: 0.5379 - val_loss: 1.2638 - val_accuracy: 0.4839
# Epoch 12/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.1503 - accuracy: 0.5606 - val_loss: 1.1419 - val_accuracy: 0.5806
# Epoch 13/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.1479 - accuracy: 0.5530 - val_loss: 1.2428 - val_accuracy: 0.5806
# Epoch 14/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.0877 - accuracy: 0.6061 - val_loss: 1.2913 - val_accuracy: 0.5161
# Epoch 15/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.0574 - accuracy: 0.5909 - val_loss: 1.2642 - val_accuracy: 0.4516
# Epoch 16/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.0703 - accuracy: 0.5606 - val_loss: 1.3394 - val_accuracy: 0.5484
# Epoch 17/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.1344 - accuracy: 0.6136 - val_loss: 1.2229 - val_accuracy: 0.5484
# Epoch 18/100
# 5/5 [==============================] - 12s 2s/step - loss: 1.0354 - accuracy: 0.5985 - val_loss: 1.1584 - val_accuracy: 0.5484
# Epoch 19/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.9822 - accuracy: 0.6288 - val_loss: 1.0989 - val_accuracy: 0.5806
# Epoch 20/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.9970 - accuracy: 0.6136 - val_loss: 1.1863 - val_accuracy: 0.5484
# Epoch 21/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.9104 - accuracy: 0.6894 - val_loss: 1.1558 - val_accuracy: 0.5806
# Epoch 22/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.9157 - accuracy: 0.6667 - val_loss: 1.1178 - val_accuracy: 0.5484
# Epoch 23/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.8723 - accuracy: 0.7197 - val_loss: 1.1085 - val_accuracy: 0.5484
# Epoch 24/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.9232 - accuracy: 0.6742 - val_loss: 1.1080 - val_accuracy: 0.6452
# Epoch 25/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.8457 - accuracy: 0.7500 - val_loss: 1.1550 - val_accuracy: 0.4839
# Epoch 26/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.8935 - accuracy: 0.7348 - val_loss: 1.1404 - val_accuracy: 0.5484
# Epoch 27/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.7710 - accuracy: 0.7879 - val_loss: 1.0410 - val_accuracy: 0.5161
# Epoch 28/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.8457 - accuracy: 0.7348 - val_loss: 0.9268 - val_accuracy: 0.7097
# Epoch 29/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.8259 - accuracy: 0.7348 - val_loss: 1.2420 - val_accuracy: 0.5161
# Epoch 30/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.7705 - accuracy: 0.7727 - val_loss: 1.0057 - val_accuracy: 0.6452
# Epoch 31/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.8497 - accuracy: 0.6970 - val_loss: 0.9489 - val_accuracy: 0.6452
# Epoch 32/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.7887 - accuracy: 0.7652 - val_loss: 1.0728 - val_accuracy: 0.6129
# Epoch 33/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.7610 - accuracy: 0.7500 - val_loss: 1.0970 - val_accuracy: 0.4839
# Epoch 34/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.7077 - accuracy: 0.8258 - val_loss: 1.0484 - val_accuracy: 0.6452
# Epoch 35/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.7404 - accuracy: 0.7424 - val_loss: 1.0050 - val_accuracy: 0.6774
# Epoch 36/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.7327 - accuracy: 0.7727 - val_loss: 1.1053 - val_accuracy: 0.7097
# Epoch 37/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.7612 - accuracy: 0.7121 - val_loss: 1.1308 - val_accuracy: 0.6129
# Epoch 38/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.7009 - accuracy: 0.7576 - val_loss: 1.0250 - val_accuracy: 0.5806
# Epoch 39/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6763 - accuracy: 0.8030 - val_loss: 0.8782 - val_accuracy: 0.7097
# Epoch 40/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6780 - accuracy: 0.7955 - val_loss: 1.0087 - val_accuracy: 0.6774
# Epoch 41/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6420 - accuracy: 0.8182 - val_loss: 1.0287 - val_accuracy: 0.6452
# Epoch 42/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6783 - accuracy: 0.7727 - val_loss: 1.1097 - val_accuracy: 0.5484
# Epoch 43/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6482 - accuracy: 0.8030 - val_loss: 0.9512 - val_accuracy: 0.6774
# Epoch 44/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.6287 - accuracy: 0.8106 - val_loss: 0.8778 - val_accuracy: 0.6452
# Epoch 45/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5952 - accuracy: 0.8636 - val_loss: 0.9704 - val_accuracy: 0.7419
# Epoch 46/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6689 - accuracy: 0.7879 - val_loss: 1.0808 - val_accuracy: 0.6129
# Epoch 47/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6302 - accuracy: 0.8182 - val_loss: 1.0347 - val_accuracy: 0.6774
# Epoch 48/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.6278 - accuracy: 0.8258 - val_loss: 0.8935 - val_accuracy: 0.6774
# Epoch 49/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6045 - accuracy: 0.8409 - val_loss: 0.8163 - val_accuracy: 0.7419
# Epoch 50/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6305 - accuracy: 0.7955 - val_loss: 1.0121 - val_accuracy: 0.7097
# Epoch 51/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.5359 - accuracy: 0.8939 - val_loss: 0.8954 - val_accuracy: 0.8065
# Epoch 52/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5861 - accuracy: 0.8258 - val_loss: 0.8678 - val_accuracy: 0.7742
# Epoch 53/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5696 - accuracy: 0.8333 - val_loss: 0.8386 - val_accuracy: 0.6774
# Epoch 54/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.6005 - accuracy: 0.8333 - val_loss: 0.8715 - val_accuracy: 0.7097
# Epoch 55/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6113 - accuracy: 0.8258 - val_loss: 0.9531 - val_accuracy: 0.6452
# Epoch 56/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5848 - accuracy: 0.8106 - val_loss: 0.8156 - val_accuracy: 0.7742
# Epoch 57/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5345 - accuracy: 0.8485 - val_loss: 0.9332 - val_accuracy: 0.7097
# Epoch 58/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.5896 - accuracy: 0.8712 - val_loss: 0.9911 - val_accuracy: 0.7097
# Epoch 59/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5609 - accuracy: 0.8409 - val_loss: 0.8800 - val_accuracy: 0.6452
# Epoch 60/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5281 - accuracy: 0.8258 - val_loss: 0.8068 - val_accuracy: 0.7097
# Epoch 61/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5057 - accuracy: 0.9015 - val_loss: 0.7915 - val_accuracy: 0.7097
# Epoch 62/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5664 - accuracy: 0.8561 - val_loss: 0.8218 - val_accuracy: 0.8065
# Epoch 63/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5463 - accuracy: 0.8258 - val_loss: 0.7937 - val_accuracy: 0.8065
# Epoch 64/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5487 - accuracy: 0.8561 - val_loss: 0.9274 - val_accuracy: 0.6452
# Epoch 65/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.5080 - accuracy: 0.8636 - val_loss: 0.7869 - val_accuracy: 0.7097
# Epoch 66/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.4763 - accuracy: 0.8636 - val_loss: 0.8399 - val_accuracy: 0.7742
# Epoch 67/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4606 - accuracy: 0.8788 - val_loss: 0.9643 - val_accuracy: 0.6129
# Epoch 68/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.5011 - accuracy: 0.8561 - val_loss: 0.8911 - val_accuracy: 0.6774
# Epoch 69/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4734 - accuracy: 0.8788 - val_loss: 0.9237 - val_accuracy: 0.6129
# Epoch 70/100
# 5/5 [==============================] - 11s 3s/step - loss: 0.4787 - accuracy: 0.8636 - val_loss: 0.8719 - val_accuracy: 0.6452
# Epoch 71/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4709 - accuracy: 0.8864 - val_loss: 0.8563 - val_accuracy: 0.7742
# Epoch 72/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4368 - accuracy: 0.9091 - val_loss: 0.8183 - val_accuracy: 0.7419
# Epoch 73/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4860 - accuracy: 0.8712 - val_loss: 0.8949 - val_accuracy: 0.6452
# Epoch 74/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4808 - accuracy: 0.8561 - val_loss: 0.8269 - val_accuracy: 0.7742
# Epoch 75/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.5328 - accuracy: 0.8485 - val_loss: 0.8804 - val_accuracy: 0.7419
# Epoch 76/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4743 - accuracy: 0.9091 - val_loss: 0.9589 - val_accuracy: 0.6774
# Epoch 77/100
# 5/5 [==============================] - 11s 3s/step - loss: 0.4481 - accuracy: 0.9167 - val_loss: 0.7331 - val_accuracy: 0.7419
# Epoch 78/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4278 - accuracy: 0.9167 - val_loss: 0.9525 - val_accuracy: 0.6774
# Epoch 79/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3981 - accuracy: 0.9015 - val_loss: 0.8539 - val_accuracy: 0.6452
# Epoch 80/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4517 - accuracy: 0.8409 - val_loss: 0.7926 - val_accuracy: 0.6774
# Epoch 81/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4666 - accuracy: 0.8864 - val_loss: 0.6759 - val_accuracy: 0.8065
# Epoch 82/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4455 - accuracy: 0.8561 - val_loss: 0.9126 - val_accuracy: 0.6452
# Epoch 83/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4390 - accuracy: 0.8788 - val_loss: 0.7467 - val_accuracy: 0.6774
# Epoch 84/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4151 - accuracy: 0.9015 - val_loss: 0.6841 - val_accuracy: 0.7419
# Epoch 85/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3771 - accuracy: 0.9318 - val_loss: 0.7981 - val_accuracy: 0.7742
# Epoch 86/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4424 - accuracy: 0.8864 - val_loss: 0.7286 - val_accuracy: 0.8065
# Epoch 87/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4392 - accuracy: 0.9015 - val_loss: 0.6981 - val_accuracy: 0.7419
# Epoch 88/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4485 - accuracy: 0.8864 - val_loss: 0.9350 - val_accuracy: 0.7097
# Epoch 89/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4349 - accuracy: 0.8864 - val_loss: 0.8315 - val_accuracy: 0.7097
# Epoch 90/100
# 5/5 [==============================] - 11s 3s/step - loss: 0.4224 - accuracy: 0.8788 - val_loss: 0.8768 - val_accuracy: 0.6452
# Epoch 91/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3826 - accuracy: 0.9015 - val_loss: 0.6552 - val_accuracy: 0.7742
# Epoch 92/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3953 - accuracy: 0.9167 - val_loss: 0.8409 - val_accuracy: 0.7097
# Epoch 93/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3870 - accuracy: 0.9091 - val_loss: 0.9415 - val_accuracy: 0.7097
# Epoch 94/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3724 - accuracy: 0.9167 - val_loss: 0.7640 - val_accuracy: 0.7742
# Epoch 95/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3918 - accuracy: 0.9015 - val_loss: 0.7936 - val_accuracy: 0.7097
# Epoch 96/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4153 - accuracy: 0.8939 - val_loss: 0.8877 - val_accuracy: 0.6774
# Epoch 97/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3468 - accuracy: 0.9545 - val_loss: 0.8236 - val_accuracy: 0.7097
# Epoch 98/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3556 - accuracy: 0.9470 - val_loss: 0.7702 - val_accuracy: 0.7419
# Epoch 99/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.3826 - accuracy: 0.9015 - val_loss: 0.7105 - val_accuracy: 0.7742
# Epoch 100/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.4249 - accuracy: 0.8788 - val_loss: 0.6746 - val_accuracy: 0.8065
# C:\Users\super\AppData\Local\Temp\ipykernel_5788\44792978.py:24: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(modelo_densenet, f'./models/{key_day}/{key_day}DENSENET{EPOCAS}.h5')

# %%
#Graficas de precisión

historial = historialDN
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(EPOCAS)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()

# %%
#MODELO MOBILENET APP

mobilenetAPP = tf.keras.applications.MobileNetV2(input_shape=(224,224,3), include_top=False, weights='imagenet')
mobilenetAPP.trainable = False

modelo_mobilenetAPP = tf.keras.Sequential([
    mobilenetAPP,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])
 
modelo_mobilenetAPP.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historialMNAPP = modelo_mobilenetAPP.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_mobilenetAPP, f'./models/{key_day}/{key_day}MOBILENETV2{EPOCAS}.h5')

# %%
#MODELO RESNETV2 APP - SOBREAJUSTE

from tensorflow.keras.applications import ResNet50V2

base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
modelo_resnet = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_resnet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 30

historialRS = modelo_resnet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_resnet, f'./models/{key_day}/{key_day}RESNET{EPOCAS}.h5')

# %%
#MODELO EFFICENTNET APP - SOBREAJUSTE 

from tensorflow.keras.applications import EfficientNetV2B0

efficent = EfficientNetV2B0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficent.trainable = False

modelo_efficent = tf.keras.Sequential([
    efficent,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_efficent.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historialE = modelo_efficent.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_efficent, f'./models/{key_day}/{key_day}EFFICENT{EPOCAS}.h5')

# %%
from tensorflow.keras.applications import InceptionV3

inception = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
inception.trainable = False

modelo_inception = tf.keras.Sequential([
    inception,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_inception.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historial_inception = modelo_inception.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_inception, f'./models/{key_day}/{key_day}INCEPTION{EPOCAS}.h5')

# %%
from tensorflow.keras.applications import NASNetMobile

nasnet = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
nasnet.trainable = False

modelo_nasnet = tf.keras.Sequential([
    nasnet,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_nasnet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historial_nasnet = modelo_nasnet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_nasnet, f'./models/{key_day}/{key_day}NASNET{EPOCAS}.h5')

# %%
#NASNET CON MEJORAS
from tensorflow.keras.applications import NASNetMobile

nasnet = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
nasnet.trainable = False

modelo_nasnet = tf.keras.Sequential([
    nasnet,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])


modelo_nasnet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 30

historial_nasnet = modelo_nasnet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_nasnet, f'./models/{key_day}/{key_day}NASNETPLUS{EPOCAS}.h5')
