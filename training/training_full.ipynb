# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import spicy
from tensorflow.keras.models import load_model
from tensorflow.keras.models import save_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense


data_dir = f'./full_data'

folders = [folder for folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, folder))]
num_hermandades = len(folders)

##CREAR GENERADORES DE IMAGENES CON DATA AUGMENTATION
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    zoom_range = [0.5, 1.5],
    validation_split=0.2 #20% para pruebas
)

##GENERADORES PARA ENTRENAMIENTO Y PRUEBAS
data_gen_entrenamiento = datagen.flow_from_directory(data_dir, target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory(data_dir, target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')
# Out:
# Found 2065 images belonging to 60 classes.
# Found 491 images belonging to 60 classes.

# %%
from tensorflow.keras.applications import DenseNet121

densenet = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
densenet.trainable = False

modelo_densenet = tf.keras.Sequential([
    densenet,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_densenet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historialDN = modelo_densenet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_densenet, f'./models/FULLDENSENET{EPOCAS}.h5')
# Out:
# WARNING:tensorflow:From c:\Users\super\OneDrive - UNIVERSIDAD DE SEVILLA\TFG\workspace\api-cofradia\venv-IA\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\super\OneDrive - UNIVERSIDAD DE SEVILLA\TFG\workspace\api-cofradia\venv-IA\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\super\OneDrive - UNIVERSIDAD DE SEVILLA\TFG\workspace\api-cofradia\venv-IA\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 65/65 [==============================] - 235s 3s/step - loss: 4.1411 - accuracy: 0.0387 - val_loss: 3.7835 - val_accuracy: 0.0631
# Epoch 2/100
# 65/65 [==============================] - 182s 3s/step - loss: 3.6245 - accuracy: 0.1094 - val_loss: 3.4780 - val_accuracy: 0.1222
# Epoch 3/100
# 65/65 [==============================] - 184s 3s/step - loss: 3.2516 - accuracy: 0.1826 - val_loss: 3.2443 - val_accuracy: 0.1976
# Epoch 4/100
# 65/65 [==============================] - 181s 3s/step - loss: 3.0146 - accuracy: 0.2450 - val_loss: 3.0880 - val_accuracy: 0.1976
# Epoch 5/100
# 65/65 [==============================] - 181s 3s/step - loss: 2.7904 - accuracy: 0.3022 - val_loss: 2.9612 - val_accuracy: 0.2627
# Epoch 6/100
# 65/65 [==============================] - 182s 3s/step - loss: 2.6371 - accuracy: 0.3370 - val_loss: 2.8328 - val_accuracy: 0.2912
# Epoch 7/100
# 65/65 [==============================] - 184s 3s/step - loss: 2.4874 - accuracy: 0.3864 - val_loss: 2.7776 - val_accuracy: 0.3116
# Epoch 8/100
# 65/65 [==============================] - 181s 3s/step - loss: 2.3657 - accuracy: 0.4058 - val_loss: 2.7016 - val_accuracy: 0.3096
# Epoch 9/100
# 65/65 [==============================] - 180s 3s/step - loss: 2.2769 - accuracy: 0.4174 - val_loss: 2.6154 - val_accuracy: 0.3585
# Epoch 10/100
# 65/65 [==============================] - 181s 3s/step - loss: 2.1938 - accuracy: 0.4489 - val_loss: 2.5175 - val_accuracy: 0.3625
# Epoch 11/100
# 65/65 [==============================] - 185s 3s/step - loss: 2.1010 - accuracy: 0.4683 - val_loss: 2.5656 - val_accuracy: 0.3340
# Epoch 12/100
# 65/65 [==============================] - 188s 3s/step - loss: 2.0475 - accuracy: 0.4770 - val_loss: 2.4731 - val_accuracy: 0.3809
# Epoch 13/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.9671 - accuracy: 0.5007 - val_loss: 2.4823 - val_accuracy: 0.3544
# Epoch 14/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.8922 - accuracy: 0.5138 - val_loss: 2.3813 - val_accuracy: 0.3788
# Epoch 15/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.8615 - accuracy: 0.5341 - val_loss: 2.3564 - val_accuracy: 0.3788
# Epoch 16/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.7904 - accuracy: 0.5574 - val_loss: 2.3289 - val_accuracy: 0.4155
# Epoch 17/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.7581 - accuracy: 0.5482 - val_loss: 2.3131 - val_accuracy: 0.4134
# Epoch 18/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.7128 - accuracy: 0.5676 - val_loss: 2.2877 - val_accuracy: 0.4175
# Epoch 19/100
# 65/65 [==============================] - 184s 3s/step - loss: 1.6617 - accuracy: 0.5806 - val_loss: 2.2812 - val_accuracy: 0.4012
# Epoch 20/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.6411 - accuracy: 0.5709 - val_loss: 2.2760 - val_accuracy: 0.4277
# Epoch 21/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.6286 - accuracy: 0.5811 - val_loss: 2.1449 - val_accuracy: 0.4562
# Epoch 22/100
# 65/65 [==============================] - 185s 3s/step - loss: 1.5645 - accuracy: 0.6039 - val_loss: 2.1481 - val_accuracy: 0.4358
# Epoch 23/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.5751 - accuracy: 0.5835 - val_loss: 2.2357 - val_accuracy: 0.4399
# Epoch 24/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.5386 - accuracy: 0.5995 - val_loss: 2.2359 - val_accuracy: 0.4175
# Epoch 25/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.5076 - accuracy: 0.6247 - val_loss: 2.1402 - val_accuracy: 0.4603
# Epoch 26/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.4810 - accuracy: 0.6053 - val_loss: 2.1402 - val_accuracy: 0.4481
# Epoch 27/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.4882 - accuracy: 0.6136 - val_loss: 2.1131 - val_accuracy: 0.4664
# Epoch 28/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.4574 - accuracy: 0.6169 - val_loss: 2.0710 - val_accuracy: 0.4521
# Epoch 29/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.4224 - accuracy: 0.6329 - val_loss: 2.0867 - val_accuracy: 0.4745
# Epoch 30/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.3978 - accuracy: 0.6208 - val_loss: 2.1709 - val_accuracy: 0.4420
# Epoch 31/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.3644 - accuracy: 0.6421 - val_loss: 2.0655 - val_accuracy: 0.4929
# Epoch 32/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.3576 - accuracy: 0.6266 - val_loss: 2.1170 - val_accuracy: 0.4297
# Epoch 33/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.3384 - accuracy: 0.6407 - val_loss: 2.0265 - val_accuracy: 0.4847
# Epoch 34/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.3392 - accuracy: 0.6295 - val_loss: 2.0718 - val_accuracy: 0.4582
# Epoch 35/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.3287 - accuracy: 0.6363 - val_loss: 2.0513 - val_accuracy: 0.4562
# Epoch 36/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.3064 - accuracy: 0.6426 - val_loss: 1.9914 - val_accuracy: 0.4379
# Epoch 37/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.2986 - accuracy: 0.6499 - val_loss: 1.9769 - val_accuracy: 0.4990
# Epoch 38/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.2744 - accuracy: 0.6591 - val_loss: 2.0254 - val_accuracy: 0.4786
# Epoch 39/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.2747 - accuracy: 0.6513 - val_loss: 2.0342 - val_accuracy: 0.4542
# Epoch 40/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.2566 - accuracy: 0.6591 - val_loss: 1.9946 - val_accuracy: 0.5071
# Epoch 41/100
# 65/65 [==============================] - 182s 3s/step - loss: 1.2465 - accuracy: 0.6659 - val_loss: 2.0172 - val_accuracy: 0.4745
# Epoch 42/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.2128 - accuracy: 0.6692 - val_loss: 1.9615 - val_accuracy: 0.5071
# Epoch 43/100
# 65/65 [==============================] - 179s 3s/step - loss: 1.2164 - accuracy: 0.6707 - val_loss: 2.0050 - val_accuracy: 0.4562
# Epoch 44/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.2171 - accuracy: 0.6707 - val_loss: 1.9449 - val_accuracy: 0.4827
# Epoch 45/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.1955 - accuracy: 0.6692 - val_loss: 1.9925 - val_accuracy: 0.4888
# Epoch 46/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.2007 - accuracy: 0.6644 - val_loss: 1.9813 - val_accuracy: 0.5051
# Epoch 47/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.1689 - accuracy: 0.6731 - val_loss: 1.8987 - val_accuracy: 0.5255
# Epoch 48/100
# 65/65 [==============================] - 179s 3s/step - loss: 1.1644 - accuracy: 0.6722 - val_loss: 2.0244 - val_accuracy: 0.4603
# Epoch 49/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.1733 - accuracy: 0.6702 - val_loss: 1.9939 - val_accuracy: 0.4929
# Epoch 50/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.1247 - accuracy: 0.6915 - val_loss: 1.9796 - val_accuracy: 0.5132
# Epoch 51/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.1380 - accuracy: 0.6780 - val_loss: 1.9109 - val_accuracy: 0.5356
# Epoch 52/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.1294 - accuracy: 0.6867 - val_loss: 1.9604 - val_accuracy: 0.4766
# Epoch 53/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.1110 - accuracy: 0.6881 - val_loss: 1.8498 - val_accuracy: 0.5010
# Epoch 54/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.1109 - accuracy: 0.6896 - val_loss: 2.0126 - val_accuracy: 0.4888
# Epoch 55/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.0773 - accuracy: 0.7036 - val_loss: 1.9151 - val_accuracy: 0.5316
# Epoch 56/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.0958 - accuracy: 0.6915 - val_loss: 1.9152 - val_accuracy: 0.5071
# Epoch 57/100
# 65/65 [==============================] - 177s 3s/step - loss: 1.1152 - accuracy: 0.6838 - val_loss: 1.8820 - val_accuracy: 0.5153
# Epoch 58/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.0949 - accuracy: 0.6891 - val_loss: 2.0972 - val_accuracy: 0.4542
# Epoch 59/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.0916 - accuracy: 0.6867 - val_loss: 2.0050 - val_accuracy: 0.5173
# Epoch 60/100
# 65/65 [==============================] - 178s 3s/step - loss: 1.0875 - accuracy: 0.6901 - val_loss: 1.9702 - val_accuracy: 0.4969
# Epoch 61/100
# 65/65 [==============================] - 186s 3s/step - loss: 1.0448 - accuracy: 0.7143 - val_loss: 2.0417 - val_accuracy: 0.4949
# Epoch 62/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0402 - accuracy: 0.7046 - val_loss: 1.9600 - val_accuracy: 0.5092
# Epoch 63/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0492 - accuracy: 0.7119 - val_loss: 1.9715 - val_accuracy: 0.5092
# Epoch 64/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0686 - accuracy: 0.6881 - val_loss: 1.9615 - val_accuracy: 0.4908
# Epoch 65/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0208 - accuracy: 0.7099 - val_loss: 1.9731 - val_accuracy: 0.5153
# Epoch 66/100
# 65/65 [==============================] - 186s 3s/step - loss: 1.0265 - accuracy: 0.7104 - val_loss: 1.9391 - val_accuracy: 0.4990
# Epoch 67/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0262 - accuracy: 0.7148 - val_loss: 1.9703 - val_accuracy: 0.5010
# Epoch 68/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0169 - accuracy: 0.7148 - val_loss: 1.9205 - val_accuracy: 0.5071
# Epoch 69/100
# 65/65 [==============================] - 181s 3s/step - loss: 1.0410 - accuracy: 0.6973 - val_loss: 1.8812 - val_accuracy: 0.5438
# Epoch 70/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0180 - accuracy: 0.7133 - val_loss: 1.9455 - val_accuracy: 0.5051
# Epoch 71/100
# 65/65 [==============================] - 180s 3s/step - loss: 1.0073 - accuracy: 0.7119 - val_loss: 1.9600 - val_accuracy: 0.5214
# Epoch 72/100
# 65/65 [==============================] - 179s 3s/step - loss: 0.9850 - accuracy: 0.7230 - val_loss: 1.9471 - val_accuracy: 0.5255
# Epoch 73/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9943 - accuracy: 0.7099 - val_loss: 1.9538 - val_accuracy: 0.5031
# Epoch 74/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9725 - accuracy: 0.7283 - val_loss: 1.8548 - val_accuracy: 0.5356
# Epoch 75/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9690 - accuracy: 0.7312 - val_loss: 1.9034 - val_accuracy: 0.5255
# Epoch 76/100
# 65/65 [==============================] - 179s 3s/step - loss: 0.9853 - accuracy: 0.7211 - val_loss: 1.9056 - val_accuracy: 0.5193
# Epoch 77/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9791 - accuracy: 0.7138 - val_loss: 1.9109 - val_accuracy: 0.5255
# Epoch 78/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9546 - accuracy: 0.7245 - val_loss: 1.9357 - val_accuracy: 0.5214
# Epoch 79/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9873 - accuracy: 0.7148 - val_loss: 1.8496 - val_accuracy: 0.5092
# Epoch 80/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9760 - accuracy: 0.7138 - val_loss: 1.9684 - val_accuracy: 0.5010
# Epoch 81/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9704 - accuracy: 0.7080 - val_loss: 1.9584 - val_accuracy: 0.5153
# Epoch 82/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9699 - accuracy: 0.7172 - val_loss: 2.0000 - val_accuracy: 0.4969
# Epoch 83/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9478 - accuracy: 0.7206 - val_loss: 1.8760 - val_accuracy: 0.5214
# Epoch 84/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9632 - accuracy: 0.7157 - val_loss: 1.9150 - val_accuracy: 0.5397
# Epoch 85/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9579 - accuracy: 0.7211 - val_loss: 1.9518 - val_accuracy: 0.5092
# Epoch 86/100
# 65/65 [==============================] - 179s 3s/step - loss: 0.9387 - accuracy: 0.7327 - val_loss: 1.9224 - val_accuracy: 0.5458
# Epoch 87/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9502 - accuracy: 0.7162 - val_loss: 1.9759 - val_accuracy: 0.5275
# Epoch 88/100
# 65/65 [==============================] - 179s 3s/step - loss: 0.9292 - accuracy: 0.7288 - val_loss: 1.9273 - val_accuracy: 0.5336
# Epoch 89/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9401 - accuracy: 0.7312 - val_loss: 1.8749 - val_accuracy: 0.5336
# Epoch 90/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9323 - accuracy: 0.7245 - val_loss: 1.9206 - val_accuracy: 0.5316
# Epoch 91/100
# 65/65 [==============================] - 179s 3s/step - loss: 0.9098 - accuracy: 0.7370 - val_loss: 1.8192 - val_accuracy: 0.5560
# Epoch 92/100
# 65/65 [==============================] - 181s 3s/step - loss: 0.9237 - accuracy: 0.7249 - val_loss: 1.8226 - val_accuracy: 0.5580
# Epoch 93/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9186 - accuracy: 0.7254 - val_loss: 1.9909 - val_accuracy: 0.4969
# Epoch 94/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.8971 - accuracy: 0.7453 - val_loss: 1.9012 - val_accuracy: 0.5540
# Epoch 95/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9094 - accuracy: 0.7400 - val_loss: 1.9221 - val_accuracy: 0.5316
# Epoch 96/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9202 - accuracy: 0.7341 - val_loss: 1.8788 - val_accuracy: 0.5560
# Epoch 97/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.9097 - accuracy: 0.7312 - val_loss: 2.0171 - val_accuracy: 0.4949
# Epoch 98/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.8956 - accuracy: 0.7395 - val_loss: 1.9404 - val_accuracy: 0.5275
# Epoch 99/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.8696 - accuracy: 0.7472 - val_loss: 1.9347 - val_accuracy: 0.5397
# Epoch 100/100
# 65/65 [==============================] - 180s 3s/step - loss: 0.8995 - accuracy: 0.7337 - val_loss: 1.9235 - val_accuracy: 0.5173
# C:\Users\super\AppData\Local\Temp\ipykernel_7340\2447667286.py:24: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(modelo_densenet, f'./models/FULLDENSENET{EPOCAS}.h5')

# %%
#Graficas de precisión

historial = historialDN
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(EPOCAS)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()

# %%
#MODELO MOBILENET APP

mobilenetAPP = tf.keras.applications.MobileNetV2(input_shape=(224,224,3), include_top=False, weights='imagenet')
mobilenetAPP.trainable = False

modelo_mobilenetAPP = tf.keras.Sequential([
    mobilenetAPP,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])
 
modelo_mobilenetAPP.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historialMNAPP = modelo_mobilenetAPP.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_mobilenetAPP, f'./models/{key_day}/{key_day}MOBILENETV2{EPOCAS}.h5')

# %%
#MODELO RESNETV2 APP - SOBREAJUSTE

from tensorflow.keras.applications import ResNet50V2

base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
modelo_resnet = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_resnet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 30

historialRS = modelo_resnet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_resnet, f'./models/{key_day}/{key_day}RESNET{EPOCAS}.h5')

# %%
#MODELO EFFICENTNET APP - SOBREAJUSTE 

from tensorflow.keras.applications import EfficientNetV2B0

efficent = EfficientNetV2B0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficent.trainable = False

modelo_efficent = tf.keras.Sequential([
    efficent,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_efficent.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historialE = modelo_efficent.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_efficent, f'./models/{key_day}/{key_day}EFFICENT{EPOCAS}.h5')

# %%
from tensorflow.keras.applications import InceptionV3

inception = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
inception.trainable = False

modelo_inception = tf.keras.Sequential([
    inception,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_inception.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historial_inception = modelo_inception.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_inception, f'./models/{key_day}/{key_day}INCEPTION{EPOCAS}.h5')

# %%
from tensorflow.keras.applications import NASNetMobile

nasnet = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
nasnet.trainable = False

modelo_nasnet = tf.keras.Sequential([
    nasnet,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])

modelo_nasnet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 100

historial_nasnet = modelo_nasnet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_nasnet, f'./models/{key_day}/{key_day}NASNET{EPOCAS}.h5')

# %%
#NASNET CON MEJORAS
from tensorflow.keras.applications import NASNetMobile

nasnet = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
nasnet.trainable = False

modelo_nasnet = tf.keras.Sequential([
    nasnet,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_hermandades, activation='softmax')
])


modelo_nasnet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

EPOCAS = 30

historial_nasnet = modelo_nasnet.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)

save_model(modelo_nasnet, f'./models/{key_day}/{key_day}NASNETPLUS{EPOCAS}.h5')
